# %%
import numpy as np
np.random.random(10)
# Out:
# array([0.74716405, 0.35262995, 0.42894279, 0.16900783, 0.89331197,
#        0.53664164, 0.04959344, 0.07985243, 0.28049195, 0.1811789 ])

# %%
! conda list
# Out:
# WARNING: The conda.compat module is deprecated and will be removed in a future release.
# # packages in environment at /home/xma/anaconda3/envs/ma:
# #
# # Name                    Version                   Build  Channel

# %%
import pandas as pd

pd.DataFrame(np.random.random(10))
# Out:
#           0
# 0  0.949241
# 1  0.026133
# 2  0.130159
# 3  0.993219
# 4  0.971732
# 5  0.639836
# 6  0.559550
# 7  0.196811
# 8  0.299372
# 9  0.303877

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.plot(np.random.rand(100))
